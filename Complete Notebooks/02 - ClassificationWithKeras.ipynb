# %% [markdown]
# <img style="float: right;" width="120" src="https://s3.eu-west-1.amazonaws.com/neueda.conygre.com/pydata/images/neueda-logo.jpeg">
# <br><br><br>

# %% [markdown]
# # Overview

# %% [markdown]
# Develop a model to predict the total dollar amount that customers are willing to pay given the following attributes:
# - Customer Name
# - Customer e-mail
# - Country
# - Gender
# - Age
# - Annual Salary
# - Credit Card Debt
# - Net Worth
#
# The model should predict:
# - Car Purchase Amount

# %% [markdown]
# # Import the python packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# # Import the data

# %%
df_cars = pd.read_excel('https://s3.eu-west-1.amazonaws.com/neueda.conygre.com/pydata/ml_intro/DL_DATA.xls',
                        sheet_name = 'CARS')

# %%
df_cars.head(10)
# Out:
#      Customer Name                                    Customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# 5     Carla Hester                                 mi@Aliquamerat.edu
# 6   Griffin Rivera                                  vehicula@at.co.uk
# 7       Orli Casey    nunc.est.mollis@Suspendissetristiqueneque.co.uk
# 8     Marny Obrien                        Phasellus@sedsemegestas.org
# 9    Rhonda Chavez                                    nec@nuncest.com
#
#           Country Gender  Age  Annual Salary  Credit Card Debt  Net Worth  \
# 0        Bulgaria      M   42          62812             11609       3490
# 1          Belize      M   41          66647              9573       3703
# 2         Algeria      F   43          53799             11160       2989
# 3    Cook Islands      F   58          79370             14426       4409
# 4          Brazil      F   57          59729              5359       3318
# 5         Liberia      F   57          68500             14179       3806
# 6           Syria      F   47          39815              5958       2212
# 7  Czech Republic      F   50          51752             10986       2875
# 8         Armenia      M   47          58139              3441       3230
# 9         Somalia      F   43          53457             12884       2970
#
#    Car Purchase Amount
# 0                35321
# 1                45116
# 2                42926
# 3                67422
# 4                55915
# 5                56612
# 6                28926
# 7                47435
# 8                48014
# 9                38190

# %% [markdown]
# # Explore the data

# %%
# we could use sns.pairplot or pandas.plotting.scatter_matrix
sns.pairplot(df_cars)

# %% [markdown]
# # Create Training and Test Data
#
# >
# >**X** - Matrix of independent variables (inputs)
# >
# >**y** - Dependent variable vector (outputs)
# >

# %%
# Remove unwanted columns

# let's drop 'Customer Name, email, country and car purchase amount' from X
X = df_cars.drop(['Customer Name', 'Customer e-mail', 'Country', 'Car Purchase Amount'], axis = 1)

# %%
X
# Out:
#     Gender  Age  Annual Salary  Credit Card Debt  Net Worth
# 0        M   42          62812             11609       3490
# 1        M   41          66647              9573       3703
# 2        F   43          53799             11160       2989
# 3        F   58          79370             14426       4409
# 4        F   57          59729              5359       3318
# ..     ...  ...            ...               ...        ...
# 495      M   41          71942              6996       3997
# 496      F   38          56039             12301       3113
# 497      F   54          68889             10612       3827
# 498      F   59          49812             14013       2767
# 499      F   47          61371              9391       3410
#
# [500 rows x 5 columns]

# %% [markdown]
# ## Encode the `Gender` column
#
# >
# >`M` ==> 0
# >
# >`F` ==> 1
# >

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder

preprocessor = make_column_transformer( (OneHotEncoder(categories='auto'),[0]),remainder="passthrough")
X['Gender'] = preprocessor.fit_transform(X)[:,0]
X
# Out:
#      Gender  Age  Annual Salary  Credit Card Debt  Net Worth
# 0       0.0   42          62812             11609       3490
# 1       0.0   41          66647              9573       3703
# 2       1.0   43          53799             11160       2989
# 3       1.0   58          79370             14426       4409
# 4       1.0   57          59729              5359       3318
# ..      ...  ...            ...               ...        ...
# 495     0.0   41          71942              6996       3997
# 496     1.0   38          56039             12301       3113
# 497     1.0   54          68889             10612       3827
# 498     1.0   59          49812             14013       2767
# 499     1.0   47          61371              9391       3410
#
# [500 rows x 5 columns]

# %%
y = df_cars['Car Purchase Amount']
y
# Out:
# 0      35321
# 1      45116
# 2      42926
# 3      67422
# 4      55915
#        ...
# 495    48901
# 496    31491
# 497    64147
# 498    45442
# 499    45107
# Name: Car Purchase Amount, Length: 500, dtype: int64

# %% [markdown]
# ## Feature Scaling
#
# Use `MinMaxScaler` to scale/normalize model to values between 0 and 1

# %%
from sklearn.preprocessing import MinMaxScaler

X_scaler = MinMaxScaler().fit(X)
X_scaled = X_scaler.transform(X)

X_scaled
# Out:
# array([[0.        , 0.44      , 0.53515   , 0.57834171, 0.5352081 ],
#        [0.        , 0.42      , 0.5830875 , 0.47603015, 0.58312711],
#        [1.        , 0.46      , 0.4224875 , 0.55577889, 0.42249719],
#        ...,
#        [1.        , 0.68      , 0.6111125 , 0.52824121, 0.61102362],
#        [1.        , 0.78      , 0.37265   , 0.69914573, 0.37255343],
#        [1.        , 0.54      , 0.5171375 , 0.46688442, 0.51721035]])

# %%
# view the max for each column in the X MinMaxScaler
X_scaler.data_max_
# Out:
# array([1.000e+00, 7.000e+01, 1.000e+05, 2.000e+04, 5.556e+03])

# %%
# view the min for each column in the X MinMaxScaler
X_scaler.data_min_
# Out:
# array([    0.,    20., 20000.,   100.,  1111.])

# %%
# we'll make y a 500x1 numpy array so it's ready for a MinMaxScaler
y = y.values.reshape(-1,1)

y.shape
# Out:
# (500, 1)

# %%
y_scaler = MinMaxScaler().fit(y)
y_scaled = y_scaler.transform(y)
y_scaled
# Out:
# array([[0.37071831],
#        [0.50867606],
#        [0.47783099],
#        [0.82284507],
#        [0.66077465],
#        [0.67059155],
#        [0.28064789],
#        [0.54133803],
#        [0.54949296],
#        [0.41112676],
#        [0.70487324],
#        [0.46885915],
#        [0.27746479],
#        [0.56702817],
#        [0.57056338],
#        [0.61995775],
#        [0.4621831 ],
#        [0.49157746],
#        [0.50188732],
#        [0.64546479],
#        [0.59339437],
#        [0.48453521],
#        [0.53860563],
#        [0.53007042],
#        [0.50814085],
#        [0.49842254],
#        [0.39664789],
#        [0.56467606],
#        [0.69507042],
#        [0.49287324],
#        [0.12091549],
#        [0.50211268],
#        [0.80794366],
#        [0.62660563],
#        [0.43394366],
#        [0.60016901],
#        [0.42223944],
#        [0.01538028],
#        [0.37928169],
#        [0.64539437],
#        [0.51839437],
#        [0.45869014],
#        [0.26804225],
#        [0.26501408],
#        [0.84053521],
#        [0.84401408],
#        [0.35515493],
#        [0.40623944],
#        [0.40680282],
#        [0.5596338 ],
#        [0.25615493],
#        [0.77095775],
#        [0.55305634],
#        [0.52649296],
#        [0.32364789],
#        [0.55070423],
#        [0.54057746],
#        [0.45669014],
#        [0.41053521],
#        [0.33433803],
#        [0.39926761],
#        [0.54202817],
#        [0.57367606],
#        [0.43794366],
#        [0.46898592],
#        [0.61908451],
#        [0.55076056],
#        [0.48846479],
#        [0.61560563],
#        [0.56891549],
#        [0.30761972],
#        [0.5686338 ],
#        [0.46343662],
#        [0.50787324],
#        [0.61960563],
#        [0.59095775],
#        [0.45573239],
#        [0.49908451],
#        [0.41552113],
#        [0.4538169 ],
#        [0.41407042],
#        [0.45714085],
#        [0.30133803],
#        [0.47019718],
#        [0.42256338],
#        [0.1486338 ],
#        [0.50939437],
#        [0.38056338],
#        [0.59067606],
#        [0.05487324],
#        [0.42190141],
#        [0.59466197],
#        [0.23904225],
#        [0.72774648],
#        [0.63485915],
#        [0.43669014],
#        [0.74076056],
#        [0.42961972],
#        [0.61232394],
#        [0.46743662],
#        [0.68226761],
#        [0.19270423],
#        [0.34705634],
#        [0.31747887],
#        [0.72480282],
#        [0.51743662],
#        [0.36343662],
#        [0.36116901],
#        [0.26178873],
#        [0.64750704],
#        [0.56539437],
#        [0.70198592],
#        [0.6803662 ],
#        [0.6048169 ],
#        [0.29916901],
#        [0.81860563],
#        [0.47053521],
#        [0.45707042],
#        [0.47314085],
#        [0.3594507 ],
#        [0.46780282],
#        [0.46357746],
#        [0.71008451],
#        [0.59722535],
#        [0.64443662],
#        [0.53722535],
#        [0.78016901],
#        [0.39792958],
#        [0.615     ],
#        [0.49297183],
#        [0.59932394],
#        [0.41188732],
#        [0.43333803],
#        [0.43771831],
#        [0.33988732],
#        [0.55807042],
#        [0.54497183],
#        [0.42830986],
#        [0.34405634],
#        [0.33380282],
#        [0.75864789],
#        [0.28769014],
#        [0.49885915],
#        [0.38938028],
#        [0.62895775],
#        [0.52080282],
#        [0.4155493 ],
#        [0.54839437],
#        [0.72143662],
#        [0.42156338],
#        [0.26492958],
#        [0.54371831],
#        [0.4698169 ],
#        [0.31409859],
#        [0.47      ],
#        [0.32164789],
#        [0.24646479],
#        [0.41088732],
#        [0.4286338 ],
#        [0.40442254],
#        [0.6778169 ],
#        [0.52750704],
#        [0.49091549],
#        [0.65623944],
#        [0.47160563],
#        [0.449     ],
#        [0.16412676],
#        [0.37238028],
#        [0.38187324],
#        [0.41101408],
#        [0.45107042],
#        [0.26605634],
#        [0.48907042],
#        [0.68212676],
#        [0.45216901],
#        [0.56409859],
#        [0.4544507 ],
#        [0.78232394],
#        [0.28242254],
#        [0.30591549],
#        [0.41919718],
#        [0.42719718],
#        [0.33250704],
#        [0.69078873],
#        [0.63925352],
#        [0.38926761],
#        [0.42988732],
#        [0.47856338],
#        [0.73050704],
#        [0.52647887],
#        [0.67014085],
#        [0.47569014],
#        [0.40676056],
#        [0.50997183],
#        [0.66519718],
#        [0.58387324],
#        [0.57353521],
#        [0.31967606],
#        [0.56647887],
#        [0.52378873],
#        [0.38150704],
#        [0.48259155],
#        [0.44591549],
#        [0.6011831 ],
#        [0.50035211],
#        [0.55660563],
#        [0.51838028],
#        [0.64577465],
#        [0.33067606],
#        [0.46773239],
#        [0.64966197],
#        [0.54907042],
#        [0.48459155],
#        [0.50108451],
#        [0.40485915],
#        [0.5465493 ],
#        [0.50488732],
#        [0.5301831 ],
#        [0.66991549],
#        [0.4601831 ],
#        [0.73405634],
#        [0.39864789],
#        [0.53369014],
#        [0.66842254],
#        [0.51422535],
#        [0.26232394],
#        [0.52661972],
#        [0.28171831],
#        [0.59656338],
#        [0.46494366],
#        [0.61484507],
#        [0.49905634],
#        [0.52190141],
#        [0.6934507 ],
#        [0.47873239],
#        [0.58735211],
#        [0.53535211],
#        [0.56901408],
#        [0.47883099],
#        [0.49908451],
#        [0.52571831],
#        [0.53305634],
#        [0.669     ],
#        [0.47569014],
#        [0.61005634],
#        [0.35408451],
#        [0.72905634],
#        [0.80505634],
#        [0.31290141],
#        [0.52302817],
#        [0.67567606],
#        [0.21385915],
#        [0.56450704],
#        [0.39569014],
#        [0.48453521],
#        [0.28298592],
#        [0.55421127],
#        [0.34170423],
#        [0.45530986],
#        [0.56811268],
#        [0.59726761],
#        [0.31338028],
#        [0.48730986],
#        [0.55352113],
#        [0.63398592],
#        [0.41795775],
#        [0.3954507 ],
#        [0.40771831],
#        [0.45521127],
#        [0.81533803],
#        [0.0498169 ],
#        [0.43026761],
#        [0.61561972],
#        [0.62680282],
#        [0.60728169],
#        [0.41839437],
#        [0.54964789],
#        [0.71104225],
#        [0.37904225],
#        [0.4511831 ],
#        [0.60183099],
#        [0.62002817],
#        [0.33560563],
#        [0.28757746],
#        [0.68256338],
#        [0.58369014],
#        [0.45880282],
#        [0.52692958],
#        [0.54380282],
#        [0.87152113],
#        [0.65553521],
#        [0.63167606],
#        [0.43528169],
#        [0.50332394],
#        [0.53432394],
#        [0.2738169 ],
#        [0.41053521],
#        [0.47532394],
#        [0.29114085],
#        [0.76109859],
#        [0.76407042],
#        [0.46932394],
#        [0.49947887],
#        [0.81819718],
#        [0.18438028],
#        [0.43692958],
#        [0.66298592],
#        [0.56960563],
#        [0.47180282],
#        [0.39556338],
#        [0.60374648],
#        [0.37628169],
#        [0.43511268],
#        [0.37719718],
#        [0.47698592],
#        [1.        ],
#        [0.72573239],
#        [0.71491549],
#        [0.43107042],
#        [0.6991831 ],
#        [0.61949296],
#        [0.58685915],
#        [0.71302817],
#        [0.19197183],
#        [0.45264789],
#        [0.62670423],
#        [0.38794366],
#        [0.48597183],
#        [0.31192958],
#        [0.31726761],
#        [0.31104225],
#        [0.51219718],
#        [0.22891549],
#        [0.43505634],
#        [0.60902817],
#        [0.43538028],
#        [0.51912676],
#        [0.30740845],
#        [0.42849296],
#        [0.36167606],
#        [0.20447887],
#        [0.27794366],
#        [0.70557746],
#        [0.58012676],
#        [0.37547887],
#        [0.52673239],
#        [0.32804225],
#        [0.56449296],
#        [0.56829577],
#        [0.45673239],
#        [0.21439437],
#        [0.49892958],
#        [0.72380282],
#        [0.47597183],
#        [0.53430986],
#        [0.69953521],
#        [0.40905634],
#        [0.42635211],
#        [0.64233803],
#        [0.42371831],
#        [0.54907042],
#        [0.52229577],
#        [0.30935211],
#        [0.37643662],
#        [0.56429577],
#        [0.56276056],
#        [0.39694366],
#        [0.53114085],
#        [0.61816901],
#        [0.29232394],
#        [0.73184507],
#        [0.43626761],
#        [0.41614085],
#        [0.67273239],
#        [0.76169014],
#        [0.65776056],
#        [0.3854507 ],
#        [0.6123662 ],
#        [0.58164789],
#        [0.39802817],
#        [0.54529577],
#        [0.28930986],
#        [0.72629577],
#        [0.38204225],
#        [0.68033803],
#        [0.60453521],
#        [0.37815493],
#        [0.47470423],
#        [0.65035211],
#        [0.24788732],
#        [0.63370423],
#        [0.54888732],
#        [0.48791549],
#        [0.46028169],
#        [0.76253521],
#        [0.3064507 ],
#        [0.79707042],
#        [0.40664789],
#        [0.47774648],
#        [0.19153521],
#        [0.86759155],
#        [0.48229577],
#        [0.41040845],
#        [0.30169014],
#        [0.77280282],
#        [0.5086338 ],
#        [0.49805634],
#        [0.14823944],
#        [0.57735211],
#        [0.74270423],
#        [0.46153521],
#        [0.52680282],
#        [0.39967606],
#        [0.34883099],
#        [0.3051831 ],
#        [0.60642254],
#        [0.30615493],
#        [0.42871831],
#        [0.41091549],
#        [0.44492958],
#        [0.74688732],
#        [0.55584507],
#        [0.43795775],
#        [0.57138028],
#        [0.31561972],
#        [0.54533803],
#        [0.37723944],
#        [0.4775493 ],
#        [0.55657746],
#        [0.51540845],
#        [0.3248169 ],
#        [0.32687324],
#        [0.37288732],
#        [0.28901408],
#        [0.6538169 ],
#        [0.46676056],
#        [0.58507042],
#        [0.36509859],
#        [0.49152113],
#        [0.42443662],
#        [0.45277465],
#        [0.21316901],
#        [0.47471831],
#        [0.42115493],
#        [0.27669014],
#        [0.60774648],
#        [0.81194366],
#        [0.47759155],
#        [0.56687324],
#        [0.25778873],
#        [0.54746479],
#        [0.71808451],
#        [0.51085915],
#        [0.        ],
#        [0.52129577],
#        [0.33756338],
#        [0.56035211],
#        [0.51866197],
#        [0.43805634],
#        [0.3726338 ],
#        [0.28953521],
#        [0.41187324],
#        [0.49902817],
#        [0.59219718],
#        [0.61366197],
#        [0.73808451],
#        [0.27414085],
#        [0.26177465],
#        [0.549     ],
#        [0.26992958],
#        [0.85449296],
#        [0.55004225],
#        [0.39949296],
#        [0.50001408],
#        [0.36815493],
#        [0.65023944],
#        [0.55470423],
#        [0.37780282],
#        [0.38757746],
#        [0.62128169],
#        [0.62040845],
#        [0.17564789],
#        [0.50726761],
#        [0.65321127],
#        [0.66915493],
#        [0.54146479],
#        [0.45760563],
#        [0.33174648],
#        [0.46457746],
#        [0.71180282],
#        [0.45566197],
#        [0.61669014],
#        [0.71997183],
#        [0.54592958],
#        [0.77729577],
#        [0.56198592],
#        [0.31677465],
#        [0.77671831],
#        [0.51326761],
#        [0.5085493 ]])

# %% [markdown]
# ## Split Data into Test and Training

# %%
# We can use the scikit learn train_test_split utility
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled)

# %% [markdown]
# # Train the model
#
# Useing Keras to build the network
# - Sequentially (from left to right)
# - Dense - all outputs are fully connected to next layer(hidden)
#
# **Dense**
# - input_dim - how many inputs (age, gender, etc)
# - units - how many neurons in the first layer
# - activation - rulu, sigmoid etc

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

model = Sequential()

# First Hidden Layer - 5 input features
layer1 = Dense(units = 7, input_dim=5, activation='relu')
model.add(layer1)

# Additional Hidden Layer - no need to specify input_dim here, Keras figures this out
layer2 = Dense(units=7, activation='relu')
model.add(layer2)

# THird Hidden Layer
layer3 = Dense(units = 7,  activation='relu')
model.add(layer3)

# Specify the output (units = 1)
model.add(Dense(units = 1, activation='linear'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 7)                 42
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 56
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 56
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 8
# =================================================================
# Total params: 162
# Trainable params: 162
# Non-trainable params: 0
# _________________________________________________________________

# %%
# compile the model

model.compile(optimizer='adam', loss='mean_squared_error')

# %% [markdown]
# ## Train (fit) the model
#
# Vary the `epochs` and `batch_size` parameters

# %%
# fit the model
epochs_hist = model.fit(X_train, y_train, epochs=40, batch_size=10,  verbose=1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/40
# 38/38 [==============================] - 0s 4ms/step - loss: 0.2593 - val_loss: 0.2015
# Epoch 2/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.1798 - val_loss: 0.1324
# Epoch 3/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.1028 - val_loss: 0.0545
# Epoch 4/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0327 - val_loss: 0.0144
# Epoch 5/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0155 - val_loss: 0.0133
# Epoch 6/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0147 - val_loss: 0.0126
# Epoch 7/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0142 - val_loss: 0.0120
# Epoch 8/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0134 - val_loss: 0.0113
# Epoch 9/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0127 - val_loss: 0.0106
# Epoch 10/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0119 - val_loss: 0.0101
# Epoch 11/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0114 - val_loss: 0.0097
# Epoch 12/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0109 - val_loss: 0.0092
# Epoch 13/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0103 - val_loss: 0.0087
# Epoch 14/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0098 - val_loss: 0.0084
# Epoch 15/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0093 - val_loss: 0.0079
# Epoch 16/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0088 - val_loss: 0.0079
# Epoch 17/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0085 - val_loss: 0.0072
# Epoch 18/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0080 - val_loss: 0.0070
# Epoch 19/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0076 - val_loss: 0.0066
# Epoch 20/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0071 - val_loss: 0.0064
# Epoch 21/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0068 - val_loss: 0.0062
# Epoch 22/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0065 - val_loss: 0.0060
# Epoch 23/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0063 - val_loss: 0.0058
# Epoch 24/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0061 - val_loss: 0.0057
# Epoch 25/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0059 - val_loss: 0.0056
# Epoch 26/40
# 38/38 [==============================] - 0s 1ms/step - loss: 0.0057 - val_loss: 0.0055
# Epoch 27/40
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0057 - val_loss: 0.0055
# Epoch 28/40
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0055 - val_loss: 0.0054
# Epoch 29/40
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0054 - val_loss: 0.0053
# Epoch 30/40
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0053
# Epoch 31/40
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0053 - val_loss: 0.0053
# Epoch 32/40
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 33/40
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0053
# Epoch 34/40
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 35/40
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0052
# Epoch 36/40
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 37/40
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0052
# Epoch 38/40
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0052
# Epoch 39/40
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0052
# Epoch 40/40
# 38/38 [==============================] - 0s 2ms/step - loss: 0.0051 - val_loss: 0.0052

# %% [markdown]
# # Evaluate the Model

# %%
# keras gives us log information from each epoch
print(epochs_hist.history.keys())
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
# we can plot this info to see how we performed during the training process
plt.plot(epochs_hist.history['loss'])
plt.plot(epochs_hist.history['val_loss'])

plt.title('Model Loss Progression During Training/Validation')
plt.ylabel('Training and Validation Losses')
plt.xlabel('Epoch Number')
plt.legend(['Training Loss', 'Validation Loss']);

# %% [markdown]
# ## Make a prediction

# %%
# Gender, Age, Annual Salary, Credit Card Debt, Net Worth
X_Testing = np.array([[1, 50, 94500, 20000, 5000]])
X_Testing_scaled = X_scaler.transform(X_Testing)
X_Testing_scaled
# Out:
# array([[1.        , 0.6       , 0.93125   , 1.        , 0.87491564]])

# %%
y_predict_scaled = model.predict(X_Testing_scaled)
y_predict = y_scaler.inverse_transform(y_predict_scaled)

print('Expected Purchase Amount=', y_predict)
# Out:
# Expected Purchase Amount= [[64324.246]]

# %% [markdown]
# # Predict the test data

# %%
y_test_pred_scaled = model.predict(X_test)
y_test_pred = y_scaler.inverse_transform(y_test_pred_scaled)
y_test_actual = y_scaler.inverse_transform(y_test)

# %%
# Plot actual vs predicted - for perfect predictions this would be a straight line
plt.plot(y_test_actual, y_test_pred, '.')
x = y = np.linspace(20000, 70000, 100)
plt.plot(x, y, '-');

# %%
result_df = pd.DataFrame({'y_test_pred': pd.Series(y_test_pred.ravel()), 'y_test_actual': pd.Series(y_test_actual.ravel())})
result_df['error'] = result_df['y_test_pred'] - result_df['y_test_actual']
result_df
# Out:
#       y_test_pred  y_test_actual         error
# 0    35444.003906        33132.0   2312.003906
# 1    60005.484375        66364.0  -6358.515625
# 2    26024.505859        24222.0   1802.505859
# 3    40033.199219        43902.0  -3868.800781
# 4    50759.335938        51866.0  -1106.664062
# ..            ...            ...           ...
# 120  46938.683594        51730.0  -4791.316406
# 121  65943.789062        67092.0  -1148.210938
# 122  41459.832031        45208.0  -3748.167969
# 123  39631.480469        38979.0    652.480469
# 124  53550.140625        63738.0 -10187.859375
#
# [125 rows x 3 columns]

# %% [markdown]
# # Vary the hyper parameters
#
# We could now begin to vary the number of neurons and check the performance and the time taken to train the network
#
# Question: if we do this, then are there consequences for the validity of our test data set?
